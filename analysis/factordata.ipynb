# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
import wrds
# Out:
# c:\Users\YeonChan Kang\anaconda3\envs\fdb\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
db = wrds.Connection()
# Out:
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
db.list_tables(library='contrib_global_factor')
# Out:
# ['global_factor']

# %%
countries = pd.read_excel('https://github.com/bkelly-lab/ReplicationCrisis/raw/master/GlobalFactors/Country%20Classification.xlsx')

# %%
countries
# Out:
#    excntry msci_development         region
# 0      USA        developed  north america
# 1      ARE         emerging    middle east
# 2      JPN        developed           asia
# 3      HKG        developed           asia
# 4      GBR        developed         europe
# ..     ...              ...            ...
# 91     UGA        not rated         africa
# 92     URY        not rated            NaN
# 93     VEN        not rated  south america
# 94     ZMB        not rated         africa
# 95     ZWE       standalone         africa
#
# [96 rows x 3 columns]

# %%
chars = pd.read_excel('https://github.com/bkelly-lab/ReplicationCrisis/raw/master/GlobalFactors/Factor%20Details.xlsx')

# %%
chars
# Out:
#     abr_hxz                                               name  \
# 0       Sue                                  Earnings surprise
# 1       Abr  Cumulative abnormal stock returns around earni...
# 2        Re        Revisions in analystsâ€™ earnings forecasts
# 3        R6             Price momentum,  prior 6-month returns
# 4       R11             Price momentum, prior 11-month returns
# ..      ...                                                ...
# 250     NaN                      Mispricing factor: Management
# 251     NaN                      Quality minus Junk: Composite
# 252     NaN                  Quality minus Junk: Profitability
# 253     NaN                         Quality minus Junk: Growth
# 254     NaN                         Quality minus Junk: Safety
#
#                                               name_new          abr_jkp  \
# 0                       Standardized earnings surprise           niq_su
# 1    Cumulative abnormal stock returns around earni...              NaN
# 2          Revisions in analystsâ€™ earnings forecasts              NaN
# 3                            Price momentum t-6 to t-1          ret_6_1
# 4                           Price momentum t-12 to t-1         ret_12_1
# ..                                                 ...              ...
# 250                      Mispricing factor: Management  mispricing_mgmt
# 251                      Quality minus Junk: Composite              qmj
# 252                  Quality minus Junk: Profitability         qmj_prof
# 253                         Quality minus Junk: Growth       qmj_growth
# 254                         Quality minus Junk: Safety       qmj_safety
#
#     time_to_create  lagged_denom                                         cite  \
# 0              NaN           NaN              Foster Olsen and Shevlin (1984)
# 1                3           NaN  Chan Jegadeesh and Lakonishok (1996) 1972/1
# 2                A           NaN  Chan Jegadeesh and Lakonishok (1996) 1976/7
# 3              NaN           NaN                  Jegadeesh and Titman (1993)
# 4              NaN           NaN                  Jegadeesh and Titman (1993)
# ..             ...           ...                                          ...
# 250            NaN           NaN                    Stambaugh and Yuan (2016)
# 251            NaN           NaN        Assness, Frazzini and Pedersen (2018)
# 252            NaN           NaN        Assness, Frazzini and Pedersen (2018)
# 253            NaN           NaN        Assness, Frazzini and Pedersen (2018)
# 254            NaN           NaN        Assness, Frazzini and Pedersen (2018)
#
#      variations     group in-sample period t-stat p-value  direction  \
# 0           3.0  Momentum      1974 - 1981   9.11     NaN        1.0
# 1           3.0  Momentum      1977 - 1993   4.25     NaN        1.0
# 2           3.0  Momentum      1977 - 1993    3.1     NaN        1.0
# 3           3.0  Momentum      1965 - 1989   2.29     NaN        1.0
# 4           3.0  Momentum      1965 - 1989    NaN     NaN        1.0
# ..          ...       ...              ...    ...     ...        ...
# 250         NaN       NEW      1967 - 2013    NaN     NaN        1.0
# 251         NaN       NEW      1957 - 2016    NaN     NaN        1.0
# 252         NaN       NEW      1957 - 2016    NaN     NaN        1.0
# 253         NaN       NEW      1957 - 2016    NaN     NaN        1.0
# 254         NaN       NEW      1957 - 2016    NaN     NaN        1.0
#
#      significance  controls
# 0             1.0       2.0
# 1             NaN       2.0
# 2             NaN       2.0
# 3             1.0       0.0
# 4             1.0       0.0
# ..            ...       ...
# 250           1.0       NaN
# 251           1.0       NaN
# 252           1.0       NaN
# 253           1.0       NaN
# 254           1.0       NaN
#
# [255 rows x 15 columns]

# %%
sql_query= f"""
          SELECT id, eom, excntry, gvkey, permno, size_grp, me, ret_exc_lead1m
                   FROM contrib.global_factor
                   WHERE common=1 and exch_main=1 and primary_sec=1 and obs_main=1 and
                   excntry='DNK'
          """

# %%
data = db.raw_sql(sql_query)
